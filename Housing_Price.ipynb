# %% [markdown]
# ### Import Libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # 🟥 Phase A: What Happened and Why? (EDA)

# %% [markdown]
# ## 1️⃣ Step 1: Collecting Data

# %%
# Loading the data into a dataframe and calling it df
df = pd.read_csv('housing_prices_assignment.csv')

# %% [markdown]
# ## 2️⃣ Step 2: Undestanding Data

# %%
# Checking the head of the dataframe df
df.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities  ... PoolArea PoolQC Fence MiscFeature MiscVal MoSold  \
# 0         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 1         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      5
# 2         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      9
# 3         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 4         Lvl    AllPub  ...        0    NaN   NaN         NaN       0     12
#
#   YrSold  SaleType  SaleCondition  SalePrice
# ...

# %%
#Checking the number of rows and columns present in df
df.shape
# Out:
# (1460, 81)

# %%
#Checking the columns present in df
df.columns
# Out:
# Index(['Id', 'MSSubClass', 'MSZoning', 'LotFrontage', 'LotArea', 'Street',
#        'Alley', 'LotShape', 'LandContour', 'Utilities', 'LotConfig',
#        'LandSlope', 'Neighborhood', 'Condition1', 'Condition2', 'BldgType',
#        'HouseStyle', 'OverallQual', 'OverallCond', 'YearBuilt', 'YearRemodAdd',
#        'RoofStyle', 'RoofMatl', 'Exterior1st', 'Exterior2nd', 'MasVnrType',
#        'MasVnrArea', 'ExterQual', 'ExterCond', 'Foundation', 'BsmtQual',
#        'BsmtCond', 'BsmtExposure', 'BsmtFinType1', 'BsmtFinSF1',
#        'BsmtFinType2', 'BsmtFinSF2', 'BsmtUnfSF', 'TotalBsmtSF', 'Heating',
#        'HeatingQC', 'CentralAir', 'Electrical', '1stFlrSF', '2ndFlrSF',
#        'LowQualFinSF', 'GrLivArea', 'BsmtFullBath', 'BsmtHalfBath', 'FullBath',
#        'HalfBath', 'BedroomAbvGr', 'KitchenAbvGr', 'KitchenQual',
#        'TotRmsAbvGrd', 'Functional', 'Fireplaces', 'FireplaceQu', 'GarageType',
#        'GarageYrBlt', 'GarageFinish', 'GarageCars', 'GarageArea', 'GarageQual',
# ...

# %%
# Understanding the enteries in a particular column 
# To check how many non-null values are present and what is the data type of those values

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 81 columns):
# Id               1460 non-null int64
# MSSubClass       1460 non-null int64
# MSZoning         1460 non-null object
# LotFrontage      1201 non-null float64
# LotArea          1460 non-null int64
# Street           1460 non-null object
# Alley            91 non-null object
# LotShape         1460 non-null object
# LandContour      1460 non-null object
# Utilities        1460 non-null object
# LotConfig        1460 non-null object
# LandSlope        1460 non-null object
# Neighborhood     1460 non-null object
# Condition1       1460 non-null object
# Condition2       1460 non-null object
# BldgType         1460 non-null object
# HouseStyle       1460 non-null object
# OverallQual      1460 non-null int64
# OverallCond      1460 non-null int64
# YearBuilt        1460 non-null int64
# YearRemodAdd     1460 non-null int64
# RoofStyle        1460 non-null object
# ...

# %%
# Understanding some basic statistical features of the data
df.describe()
# Out:
#                 Id   MSSubClass  LotFrontage        LotArea  OverallQual  \
# count  1460.000000  1460.000000  1201.000000    1460.000000  1460.000000
# mean    730.500000    56.897260    70.049958   10516.828082     6.099315
# std     421.610009    42.300571    24.284752    9981.264932     1.382997
# min       1.000000    20.000000    21.000000    1300.000000     1.000000
# 25%     365.750000    20.000000    59.000000    7553.500000     5.000000
# 50%     730.500000    50.000000    69.000000    9478.500000     6.000000
# 75%    1095.250000    70.000000    80.000000   11601.500000     7.000000
# max    1460.000000   190.000000   313.000000  215245.000000    10.000000
#
#        OverallCond    YearBuilt  YearRemodAdd   MasVnrArea   BsmtFinSF1  ...  \
# count  1460.000000  1460.000000   1460.000000  1452.000000  1460.000000  ...
# mean      5.575342  1971.267808   1984.865753   103.685262   443.639726  ...
# std       1.112799    30.202904     20.645407   181.066207   456.098091  ...
# ...

# %%
# Checking the distribution of values in target feature SalePrice
sns.distplot(df['SalePrice'])
plt.tight_layout()

# %% [markdown]
# ## 3️⃣ Step 3: Cleaning Data

# %%
# Checking which columns have missing values
df.columns[df.isnull().any()].tolist()
# Out:
# ['LotFrontage',
#  'Alley',
#  'MasVnrType',
#  'MasVnrArea',
#  'BsmtQual',
#  'BsmtCond',
#  'BsmtExposure',
#  'BsmtFinType1',
#  'BsmtFinType2',
#  'Electrical',
#  'FireplaceQu',
#  'GarageType',
#  'GarageYrBlt',
#  'GarageFinish',
#  'GarageQual',
#  'GarageCond',
#  'PoolQC',
#  'Fence',
#  'MiscFeature']

# %%
# Checking the total number of missing values in the columns

pd.set_option("display.max_rows", 100) #this will display all the rows in the result

df.isnull().sum().sort_values(ascending = False)
# Out:
# PoolQC           1453
# MiscFeature      1406
# Alley            1369
# Fence            1179
# FireplaceQu       690
# LotFrontage       259
# GarageCond         81
# GarageType         81
# GarageYrBlt        81
# GarageFinish       81
# GarageQual         81
# BsmtExposure       38
# BsmtFinType2       38
# BsmtFinType1       37
# BsmtCond           37
# BsmtQual           37
# MasVnrArea          8
# MasVnrType          8
# Electrical          1
# Utilities           0
# YearRemodAdd        0
# MSSubClass          0
# Foundation          0
# ExterCond           0
# ExterQual           0
# Exterior2nd         0
# Exterior1st         0
# RoofMatl            0
# RoofStyle           0
# YearBuilt           0
# LotConfig           0
# OverallCond         0
# OverallQual         0
# HouseStyle          0
# BldgType            0
# Condition2          0
# BsmtFinSF1          0
# MSZoning            0
# LotArea             0
# Street              0
# Condition1          0
# ...

# %%
# Visualizing the presence of missing values

plt.figure(figsize=(20,5))
sns.heatmap(df.isnull(),yticklabels=False, cbar=False)

# %% [markdown]
# **The columns 'Alley', 'FireplaceQu', 'PoolQC', 'Fence', 'MiscFeature' contain too many missing values. They will be dropped from dataframe. The rest of the columns with missing values will be filled with either the mean (for numerical features) or mode (for categorical features)**

# %%
# Dropping columns
df.drop(['Alley', 'FireplaceQu', 'PoolQC', 'Fence', 'MiscFeature'], axis=1, inplace=True)

# %%
# Checking the shape of df after dropping columns
df.shape
# Out:
# (1460, 76)

# %%
# Visualizing the presence of missing values

plt.figure(figsize=(20,5))
sns.heatmap(df.isnull(),yticklabels=False, cbar=False)

# %% [markdown]
# **In order to replace these remaining missing values, it is important to check which columns contain the numerical (integer and float) values and which columns contain 'object' type values**

# %%
# Obtaining the columns containing integer and floating point values

df.select_dtypes(include=['int64', 'float64']).columns
# Out:
# Index(['Id', 'MSSubClass', 'LotFrontage', 'LotArea', 'OverallQual',
#        'OverallCond', 'YearBuilt', 'YearRemodAdd', 'MasVnrArea', 'BsmtFinSF1',
#        'BsmtFinSF2', 'BsmtUnfSF', 'TotalBsmtSF', '1stFlrSF', '2ndFlrSF',
#        'LowQualFinSF', 'GrLivArea', 'BsmtFullBath', 'BsmtHalfBath', 'FullBath',
#        'HalfBath', 'BedroomAbvGr', 'KitchenAbvGr', 'TotRmsAbvGrd',
#        'Fireplaces', 'GarageYrBlt', 'GarageCars', 'GarageArea', 'WoodDeckSF',
#        'OpenPorchSF', 'EnclosedPorch', '3SsnPorch', 'ScreenPorch', 'PoolArea',
#        'MiscVal', 'MoSold', 'YrSold', 'SalePrice'],
#       dtype='object')

# %%
# Obtaining the columns containing 'object' values

df.select_dtypes(include=['object']).columns
# Out:
# Index(['MSZoning', 'Street', 'LotShape', 'LandContour', 'Utilities',
#        'LotConfig', 'LandSlope', 'Neighborhood', 'Condition1', 'Condition2',
#        'BldgType', 'HouseStyle', 'RoofStyle', 'RoofMatl', 'Exterior1st',
#        'Exterior2nd', 'MasVnrType', 'ExterQual', 'ExterCond', 'Foundation',
#        'BsmtQual', 'BsmtCond', 'BsmtExposure', 'BsmtFinType1', 'BsmtFinType2',
#        'Heating', 'HeatingQC', 'CentralAir', 'Electrical', 'KitchenQual',
#        'Functional', 'GarageType', 'GarageFinish', 'GarageQual', 'GarageCond',
#        'PavedDrive', 'SaleType', 'SaleCondition'],
#       dtype='object')

# %% [markdown]
# **Numeric** type missing values columns are 'LotFrontage','MasVnrArea','GarageYrBlt',
#
# **Object** type missing values columns are 'GarageFinish','GarageQual','GarageCond','MasVnrType', 'BsmtQual','BsmtCond','BsmtExposure', 'BsmtFinType1','BsmtFinType2','Electrical','GarageType',

# %%
# Filling missing values for numeric column

df['LotFrontage'] = df['LotFrontage'].fillna(df['LotFrontage'].mean())
df['MasVnrArea'] = df['MasVnrArea'].fillna(df['MasVnrArea'].mean())
df['GarageYrBlt'] = df['GarageYrBlt'].fillna(df['GarageYrBlt'].mean())

# %%
# Filling missing values for categorical columns

df['GarageFinish'] = df['GarageFinish'].fillna(df['GarageFinish'].mode()[0])
df['GarageQual'] = df['GarageQual'].fillna(df['GarageQual'].mode()[0])
df['GarageCond'] = df['GarageCond'].fillna(df['GarageCond'].mode()[0])
df['MasVnrType'] = df['MasVnrType'].fillna(df['MasVnrType'].mode()[0])
df['BsmtQual'] = df['BsmtQual'].fillna(df['BsmtQual'].mode()[0])
df['BsmtCond'] = df['BsmtCond'].fillna(df['BsmtCond'].mode()[0])
df['BsmtExposure'] = df['BsmtExposure'].fillna(df['BsmtExposure'].mode()[0])
df['BsmtFinType1'] = df['BsmtFinType1'].fillna(df['BsmtFinType1'].mode()[0])
df['BsmtFinType2'] = df['BsmtFinType2'].fillna(df['BsmtFinType2'].mode()[0])
df['Electrical'] = df['Electrical'].fillna(df['Electrical'].mode()[0])
df['GarageType'] = df['GarageType'].fillna(df['GarageType'].mode()[0])

# %%
# Checking if there is any missing value present in the data at this stage

print("The number of missing values in the data is:",df.isnull().any().sum())
# Out:
# The number of missing values in the data is: 0

# %% [markdown]
# **There are no missing values left in the data**

# %% [markdown]
# ## 4️⃣ Step 4: Statistical Analysis

# %%
# Checking the average, minimum and maximum values in the target column

display( 
    df['SalePrice'].mean(), 
    df['SalePrice'].min(), 
    df['SalePrice'].max())
# Out:
# 180921.19589041095
# 34900
# 755000

# %% [markdown]
# ### **Checking the correlation between different features of data and understanding how SalePrice is related to other features**

# %%
# Visualizing the correlation among all the features of data

plt.figure(figsize=(25,15))
sns.heatmap(df.corr(),cmap='coolwarm', annot=True, cbar=False)

# %%
# Visualizing the correlation of target feature (SalePrice) with other features

plt.figure(figsize=(10,6))
df.corrwith(df['SalePrice']).plot(kind='bar')

# %%
# Getting the numerical values of correlation of target feature (SalePrice) with other features

df.corrwith(df['SalePrice']).sort_values(ascending=False)
# Out:
# SalePrice        1.000000
# OverallQual      0.790982
# GrLivArea        0.708624
# GarageCars       0.640409
# GarageArea       0.623431
# TotalBsmtSF      0.613581
# 1stFlrSF         0.605852
# FullBath         0.560664
# TotRmsAbvGrd     0.533723
# YearBuilt        0.522897
# YearRemodAdd     0.507101
# MasVnrArea       0.475241
# GarageYrBlt      0.470177
# Fireplaces       0.466929
# BsmtFinSF1       0.386420
# LotFrontage      0.334901
# WoodDeckSF       0.324413
# 2ndFlrSF         0.319334
# OpenPorchSF      0.315856
# HalfBath         0.284108
# LotArea          0.263843
# BsmtFullBath     0.227122
# BsmtUnfSF        0.214479
# BedroomAbvGr     0.168213
# ScreenPorch      0.111447
# PoolArea         0.092404
# MoSold           0.046432
# 3SsnPorch        0.044584
# BsmtFinSF2      -0.011378
# BsmtHalfBath    -0.016844
# MiscVal         -0.021190
# Id              -0.021917
# LowQualFinSF    -0.025606
# YrSold          -0.028923
# OverallCond     -0.077856
# ...

# %%
# Plotting SalesPrice vs. Features where df.corr()>0.5 to visualize the trend

fig, ax =plt.subplots(3,3,figsize=(12,10))
sns.scatterplot(x='OverallQual',y='SalePrice', data=df, ax=ax[0,0])
sns.scatterplot(x='GrLivArea',y='SalePrice', data=df,ax=ax[0,1])
sns.scatterplot(x='GarageCars',y='SalePrice', data=df,ax=ax[0,2])
sns.scatterplot(x='GarageArea',y='SalePrice', data=df, ax=ax[1,0])
sns.scatterplot(x='TotalBsmtSF',y='SalePrice', data=df,ax=ax[1,1])
sns.scatterplot(x='1stFlrSF',y='SalePrice', data=df,ax=ax[1,2])
sns.scatterplot(x='FullBath',y='SalePrice', data=df, ax=ax[2,0])
sns.scatterplot(x='TotRmsAbvGrd',y='SalePrice', data=df,ax=ax[2,1])
sns.scatterplot(x='YearBuilt',y='SalePrice', data=df,ax=ax[2,2])

plt.tight_layout()

# %% [markdown]
# # 🟥🟥 Phase B: What Will Happen? (AI Models)

# %% [markdown]
# ### Getting dummies for categorical variables

# %%
# Selecting the columns for which dummy variables are required
column_for_dummies = ['MSZoning', 'Street', 'LotShape', 'LandContour', 'Utilities',
       'LotConfig', 'LandSlope', 'Neighborhood', 'Condition1', 'Condition2',
       'BldgType', 'HouseStyle', 'RoofStyle', 'RoofMatl', 'Exterior1st',
       'Exterior2nd', 'MasVnrType', 'ExterQual', 'ExterCond', 'Foundation',
       'BsmtQual', 'BsmtCond', 'BsmtExposure', 'BsmtFinType1', 'BsmtFinType2',
       'Heating', 'HeatingQC', 'CentralAir', 'Electrical', 'KitchenQual',
       'Functional', 'GarageType', 'GarageFinish', 'GarageQual', 'GarageCond',
       'PavedDrive', 'SaleType', 'SaleCondition']

# Getting dummies for categorical variables and storing the result in a new dataframe called final_df
final_df = pd.get_dummies(df, columns=column_for_dummies, drop_first=True)

# %%
# Checking the shape of final dataframe after getting dummy variables

final_df.shape
# Out:
# (1460, 234)

# %%
# Checking the head of final dataframe

final_df.head()
# Out:
#    Id  MSSubClass  LotFrontage  LotArea  OverallQual  OverallCond  YearBuilt  \
# 0   1          60         65.0     8450            7            5       2003
# 1   2          20         80.0     9600            6            8       1976
# 2   3          60         68.0    11250            7            5       2001
# 3   4          70         60.0     9550            7            5       1915
# 4   5          60         84.0    14260            8            5       2000
#
#    YearRemodAdd  MasVnrArea  BsmtFinSF1  ...  SaleType_ConLI  SaleType_ConLw  \
# 0          2003       196.0         706  ...               0               0
# 1          1976         0.0         978  ...               0               0
# 2          2002       162.0         486  ...               0               0
# 3          1970         0.0         216  ...               0               0
# 4          2000       350.0         655  ...               0               0
#
# ...

# %%
# Checking the data types for all the columns of final dataframe to check whether all the columns are numeric or not

pd.set_option("display.max_rows", 300) #this will display all the rows in the result

final_df.dtypes
# Out:
# Id                         int64
# MSSubClass                 int64
# LotFrontage              float64
# LotArea                    int64
# OverallQual                int64
# OverallCond                int64
# YearBuilt                  int64
# YearRemodAdd               int64
# MasVnrArea               float64
# BsmtFinSF1                 int64
# BsmtFinSF2                 int64
# BsmtUnfSF                  int64
# TotalBsmtSF                int64
# 1stFlrSF                   int64
# 2ndFlrSF                   int64
# LowQualFinSF               int64
# GrLivArea                  int64
# BsmtFullBath               int64
# BsmtHalfBath               int64
# FullBath                   int64
# HalfBath                   int64
# BedroomAbvGr               int64
# KitchenAbvGr               int64
# TotRmsAbvGrd               int64
# Fireplaces                 int64
# GarageYrBlt              float64
# GarageCars                 int64
# GarageArea                 int64
# ...

# %%
# The 'ID' column will not provide any meaningful information of House Prices so it's better to drop it

final_df.drop(['Id'], axis=1, inplace=True)

# %%
# Checking the shape of final dataframe

final_df.shape
# Out:
# (1460, 233)

# %% [markdown]
# ## 5️⃣ Step 5: Predictive Modeling

# %% [markdown]
# ### Splitting the data into training set and test set

# %%
# Assigning the input features to 'X' and target column to 'y'

X = final_df.drop('SalePrice', axis=1).values
y = final_df['SalePrice'].values

# %%
# importing required library
from sklearn.model_selection import train_test_split

#Splitting the data into training and test set
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.30, random_state=42)

# %% [markdown]
# ### Training model

# %%
# importing the required library
from sklearn.ensemble import RandomForestRegressor

# defining the model
model = RandomForestRegressor()

#fitting the model to training data
model.fit(X_train,y_train)

print('Accuracy of Random Forest regressor on training set: {:.2f}'.format(model.score(X_train, y_train))) #accuracy on training data
print('Accuracy of Random Forest regressor on test set: {:.2f}'.format(model.score(X_test, y_test))) #accuracy on test data
# Out:
# Accuracy of Random Forest regressor on training set: 0.97
# Accuracy of Random Forest regressor on test set: 0.90

# %% [markdown]
# ### Making predictions from the model

# %%
# Making predictions on test set

y_pred = model.predict(X_test)

# %%
# getting the values of actual test data and predicted values and putting them in a dataframe called 'result_df' to compare them side by side

result_df = pd.DataFrame({'Actual Data':y_test, 'Predictions':y_pred})
print(result_df)
# Out:
#      Actual Data  Predictions
# 0         154500    142011.50
# 1         325000    305386.92
# 2         115000    116240.00
# 3         159000    150716.00
# 4         315500    312526.09
# ..           ...          ...
# 433       139000    137095.00
# 434       126175    130686.50
# 435       205950    197081.09
# 436       110000    130688.39
# 437       485000    414564.69
#
# [438 rows x 2 columns]

# %%
# Plotting the actual test values vs. the predicted values by model

sns.scatterplot(y_test,y_pred)

# %%
# Plotting the difference between the Test data set and predicted valuesby model
# We expect the difference to be normally distributed aroud zero if the model is making good predictions

sns.distplot(y_test-y_pred)

# %% [markdown]
# # 🟥🟥🟥 Phase C: Are You Sure? (Model Evaluation)

# %% [markdown]
# ## 6️⃣ Step 6: Evaluation

# %%
# Importing required performance metrics
from sklearn.metrics import mean_absolute_error, mean_squared_error

# Getting the values of various performance metrics
print('Mean Absolute Error: {:.2f}'.format(mean_absolute_error(y_test, y_pred)))
print('Mean Squared Error:{:.2f}'.format(mean_squared_error(y_test, y_pred)))
print('Root Mean Squared Error:{:.2f}'.format(np.sqrt(mean_squared_error(y_test, y_pred))))
# Out:
# Mean Absolute Error: 16780.22
# Mean Squared Error:719901163.25
# Root Mean Squared Error:26830.97

# %%
# Checking the R-squared (R2) score

# Importing the required library
from sklearn.metrics import r2_score

# Getting the R2 score
print('R2: {:.2f}'.format(r2_score(y_test, y_pred)))
# Out:
# R2: 0.90

# %% [markdown]
# ### Summary of Analysis

# %% [markdown]
# In order to predict the Sale Price of the houses in an area, a dataset (1460 rows X 81 columns) has been analysed. The Sale Price is found to be correlated with various features such as Overall Quality of the house, Living Area, Garage Area and Basement Area. A Random Forest Regression model has been utilized to predict the Sale Price of the house and the initial results are presented.
#
# The accuracy of this model on training set is found to be 97% whereas on the test set, it is 90%. The Root Mean Squared error is 26830.97. The R2 (R-squared) score is 0.90 which means that the model can explain 90% of the variance of data. However, there is a lot of scope of improvement in the model predictions.
